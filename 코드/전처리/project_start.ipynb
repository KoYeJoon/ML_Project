# %%
import json
import pandas as pd 
import matplotlib.pyplot as plt

yelp = pd.read_pickle("partygirl")

#read the first 6000k entries
#stop = 6000000

all_data=list()

for i, line in enumerate(yelp):
    data = json.loads(line)
    #keylist = data.keys()
    if 'overall' in data.keys():
        if 'reviewText' in data.keys():
                if 'summary' in data.keys():
                    overall = data['overall']
                    reviewText = data['reviewText']
                    summary = data['summary']
                    all_data.append([overall,reviewText,summary])

                    
    
    
df = pd.DataFrame(all_data)
df= pd.DataFrame(all_data,columns = ['overall','reviewText','summary'])
print(df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-54e61942e4f2> in <module>()
#       3 import matplotlib.pyplot as plt
#       4
# ----> 5 yelp = pd.read_pickle("partygirl")
#       6
#       7 #read the first 6000k entries
#
# /usr/local/lib/python3.6/dist-packages/pandas/io/pickle.py in read_pickle(filepath_or_buffer, compression)
#     180                 # We want to silence any warnings about, e.g. moved modules.
#     181                 warnings.simplefilter("ignore", Warning)
# --> 182                 return pickle.load(f)
#     183         except excs_to_catch:
#     184             # e.g.
#
# ValueError: unsupported pickle protocol: 5

# %%
for i, line in enumerate(yelp):
    data = json.loads(line)
    #keylist = data.keys()
    if 'overall' in data.keys():
        if 'reviewText' in data.keys():
                if 'summary' in data.keys():
                    overall = data['overall']
                    reviewText = data['reviewText'].lower()
                    summary = data['summary'].lower()
                    all_data.append([overall,reviewText,summary])


# for i in range(len(reviewText)):
#     line_f=' '.join(reviewText[i])
#     #don't erase [?,:,"]
#     line_f=reviewText.sub(emoji_pattern,'',line_f)
#     line_f=reviewText.sub('[-=+,#/\^$.@*\※~&%ㆍ!’』\\‘|\(\)\[\]\<\>`“\'…》;]','',line_f)
#     reviewText.append(line_f)
    
df = pd.DataFrame(all_data)
df= pd.DataFrame(all_data,columns = ['overall','reviewText','summary'])
print(df)
# Out:
#          overall                                         reviewText  \
# 0            5.0  This is a great cd full of worship favorites!!...
# 1            5.0  So creative!  Love his music - the words, the ...
# 2            5.0  Keith Green, gone far to early in his carreer,...
# 3            5.0  Keith Green had his special comedy style of Ch...
# 4            5.0  Keith Green / So you wanna go back to Egypt......
# ...          ...                                                ...
# 1582188      5.0  Casting Crowns....you do it so well! Awesome s...
# 1582189      4.0  This band has produced many inspiring Christia...
# 1582190      5.0  Awesome band and awesome song. This is my next...
# 1582191      5.0                                          Excellent
# 1582192      5.0  This is a moving song. I used it on Easter mor...
#
#                                                    summary
# 0                                         Great worship cd
# ...

# %%
from nltk.tokenize import TreebankWordTokenizer
tokenizer=TreebankWordTokenizer()
import nltk  
nltk.download('punkt')
from nltk.tokenize import word_tokenize  
import re
# Out:
# [nltk_data] Downloading package punkt to /Users/yejoonko/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
#불용어 제거를 위한 모듈
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words=set(stopwords.words('english'))


#알파벳 소문자 이외의 문자들(“,!,?,’,(,),@ 등)은 공백으로 변환
from nltk.corpus import stopwords
emoji_pattern = re.compile("["
                u"\U0001F600-\U0001F64F"  # emoticons
                u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                u"\U0001F680-\U0001F6FF"  # transport & map symbols
                u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                u"\U00002702-\U000027B0"
                u"\U000024C2-\U0001F251"
                u"\U0001f926-\U0001f937"
                u'\U00010000-\U0010ffff'
                u"\u200d"
                u"\u2640-\u2642"
                u"\u2600-\u2B55"
                u"\u23cf"
                u"\u23e9"
                u"\u231a"
                u"\u3030"
                u"\ufe0f"
    "]+", flags=re.UNICODE)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/yejoonko/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import numpy as np
X=[]

#row i and column 1 -> 댓글들만 가져오기 
line=np.array(df.loc[:,'reviewText']) 
for i in range(100):
    line3=str(line[i])
    line3=line3.lower()
    line2=tokenizer.tokenize(line3) 
    X.append(line2)
print(X)
# Out:
# [['this', 'is', 'a', 'great', 'cd', 'full', 'of', 'worship', 'favorites', '!', '!', 'all', 'time', 'great', 'keith', 'green', 'songs.', 'his', 'best', 'album', 'by', 'far', '.'], ['so', 'creative', '!', 'love', 'his', 'music', '-', 'the', 'words', ',', 'the', 'message', '!', 'some', 'of', 'my', 'favorite', 'songs', 'on', 'this', 'cd.', 'i', 'should', 'have', 'bought', 'it', 'years', 'ago', '!'], ['keith', 'green', ',', 'gone', 'far', 'to', 'early', 'in', 'his', 'carreer', ',', 'left', 'us', 'with', 'these', 'few', 'golden', 'alblums', 'to', 'bless', 'us', 'and', 'let', 'us', 'see', 'from', 'a', 'more', 'in', 'sync', 'world', 'veiw', 'or', 'i', 'should', 'say', '``', 'the', 'language', 'of', 'the', 'modern', "world'.", 'had', 'this', 'on', 'lp', 'all', 'his', 'alblums..look', 'for', 'ammples', 'and', 'then', 'you', 'will', 'wee', 'what', 'i', 'am', 'talking', 'about.', 'god', 'bless', 'you', 'all'], ['keith', 'green', 'had', 'his', 'special', 'comedy', 'style', 'of', 'chirstian', 'mus
# ...

# %%
# 어간추출(stemming) - 품사의 정보가 보존되지 않음.  
# vs 표제어 추출(lemmatization) - 품사의 정보가 보존됨.
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer 
n=WordNetLemmatizer()

x_data=[]

for i in X:
        result=[]
        for w in i:
            #표제어 추출
            w=n.lemmatize(w)
            #불용어 제거
            if w not in stop_words:
                result.append(w)

        x_data.append(result)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/yejoonko/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
x2_data=[]

for i in range(len(x_data)):
    line_f=' '.join(x_data[i])
    #don't erase [?,:,"]
    line_f=re.sub(emoji_pattern,'',line_f)
    line_f=re.sub('[-=+,#/\^$.@*\※~&%ㆍ!’』\\‘|\(\)\[\]\<\>`“\'…》;]','',line_f)
    x2_data.append(line_f)

# %%
print(len(x2_data))
print(x2_data)
# Out:
# 100
# ...

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import json # import json module
from nltk.tokenize import TreebankWordTokenizer
tokenizer=TreebankWordTokenizer()
import nltk  
nltk.download('punkt')
from nltk.tokenize import word_tokenize  
import re


yelp = open('/Users/yejoonko/dataset/project/Digital_Music.json')


#read the first 6000k entries
#stop = 6000000

all_data=list()

for i, line in enumerate(yelp):
    data = json.loads(line)
    #keylist = data.keys()
    if 'overall' in data.keys():
        if 'reviewText' in data.keys():
                if 'summary' in data.keys():
                    overall = data['overall']
                    reviewText = data['reviewText'].lower()
                    summary = data['summary'].lower()
                    all_data.append([overall,reviewText,summary])


# for i in range(len(reviewText)):
#     line_f=' '.join(reviewText[i])
#     #don't erase [?,:,"]
#     line_f=reviewText.sub(emoji_pattern,'',line_f)
#     line_f=reviewText.sub('[-=+,#/\^$.@*\※~&%ㆍ!’』\\‘|\(\)\[\]\<\>`“\'…》;]','',line_f)
#     reviewText.append(line_f)
    
df= pd.DataFrame(all_data,columns = ['overall','reviewText','summary'])
# print(df)


from nltk.tokenize import TreebankWordTokenizer
tokenizer=TreebankWordTokenizer()
import nltk  
nltk.download('punkt')
from nltk.tokenize import word_tokenize  
import re
import csv

#불용어 제거를 위한 모듈
from nltk.corpus import stopwords
nltk.download('stopwords')
stop_words=set(stopwords.words('english'))


#알파벳 소문자 이외의 문자들(“,!,?,’,(,),@ 등)은 공백으로 변환
from nltk.corpus import stopwords
emoji_pattern = re.compile("["
                u"\U0001F600-\U0001F64F"  # emoticons
                u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                u"\U0001F680-\U0001F6FF"  # transport & map symbols
                u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                u"\U00002702-\U000027B0"
                u"\U000024C2-\U0001F251"
                u"\U0001f926-\U0001f937"
                u'\U00010000-\U0010ffff'
                u"\u200d"
                u"\u2640-\u2642"
                u"\u2600-\u2B55"
                u"\u23cf"
                u"\u23e9"
                u"\u231a"
                u"\u3030"
                u"\ufe0f"
    "]+", flags=re.UNICODE)
    
import numpy as np
X=[]

all_data = all_data[:60000]

#row i and column 1 -> 댓글들만 가져오기 
line=np.array(df.loc[:,'reviewText']) 
for i in range(len(all_data)):
    line3=str(line[i])
    line3=line3.lower()
    line2=tokenizer.tokenize(line3) 
    X.append(line2)
# print(X)



# 어간추출(stemming) - 품사의 정보가 보존되지 않음.  
# vs 표제어 추출(lemmatization) - 품사의 정보가 보존됨.
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer 
n=WordNetLemmatizer()

x_data=[]

for i in X:
        result=[]
        for w in i:
            #표제어 추출
            w=n.lemmatize(w)
            #불용어 제거
            if w not in stop_words:
                result.append(w)

        x_data.append(result)
        
        
        
x2_data=[]

for i in range(len(x_data)):
    line_f=' '.join(x_data[i])
    #don't erase [?,:,"]
    line_f=re.sub(emoji_pattern,'',line_f)
    line_f=re.sub('[-=+,#/\^$.@*\※~&%ㆍ!’』\\‘|\(\)\[\]\<\>`“\'…》;]','',line_f)
    x2_data.append(line_f)
    
data = pd.DataFrame(all_data)
pro_data = pd.DataFrame(x2_data)

new_data = pd.concat([data, pro_data],axis =1)
new_data.columns = ['overall','reviewText','summary','pretreatment']

# print(new_data)
#new_data = pd.read_pickle('new_data')
new_data.to_pickle('new_data_60000')
#new_data.to_csv('new_data.csv')
#new_data = pd.read_pickle('new_data')
# Out:
# [nltk_data] Downloading package punkt to /Users/yejoonko/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/yejoonko/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/yejoonko/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/yejoonko/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
new_data = pd.read_pickle('new_data_60000')
new_data.head()
len(new_data)
# Out:
# 60000
